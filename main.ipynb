# %%
from bs4 import BeautifulSoup as soup
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import re
import pandas as pd
import matplotlib.pyplot as plt
import time
import locale

# %%
driver = webdriver.Chrome()

# %%
base_url = 'https://www.facebook.com/marketplace/concepcion/search?'
new_base_url = "https://www.facebook.com/marketplace/concepcion/vehicles?minPrice=3000000&maxPrice=5000000&sortBy=creation_time_descend&exact=false"
min_price = 3000000
max_price = 5000000
days_since_listed = 10
min_mileage = 50
min_year = 2010
max_year = 2023
make = 'chevrolet'
model = 'sonic'
query = 'car'
url = f'{base_url}minPrice={min_price}&maxPrice={max_price}&daysSinceListed={days_since_listed}&sortBy=creation_time_descend&query={query}'

# %%
driver.get(url)

# %%
scroll_count = 4
scroll_delay = 2
scroll_down = "window.scrollTo(0, document.body.scrollHeight);"

# %%
script = """
var botonCerrar = document.querySelector('.x1i10hfl.x1ejq31n.xd10rxx.x1sy0etr.x17r0tee.x1ypdohk.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x16tdsg8.x1hl2dhg.xggy1nq.x87ps6o.x1lku1pv.x1a2a7pz.x6s0dn4.xzolkzo.x12go9s9.x1rnf11y.xprq8jg.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x78zum5.xl56j7k.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6.xc9qbxq.x14qfxbe.x1qhmfi1');
if (botonCerrar) {
    botonCerrar.click();
} else {
    console.log('No se encontró el botón de cerrar la ventana emergente.');
}
"""
time.sleep(2)
driver.execute_script(script)

# %%
for _ in range(scroll_count):
    driver.execute_script(scroll_down)
    time.sleep(scroll_delay)

# %%
market_soup = soup(driver.page_source, 'html.parser')

# %%
#browser.quit()
print(market_soup)
# Out:
# <html class="_9dls __fb-light-mode" dir="ltr" id="facebook" lang="es"><head><link data-badged-icon="https://static.xx.fbcdn.net/rsrc.php/yD/r/UJj0tgk-RrT.ico" data-default-icon="https://static.xx.fbcdn.net/rsrc.php/yT/r/aGT3gskzWBf.ico" href="https://static.xx.fbcdn.net/rsrc.php/yT/r/aGT3gskzWBf.ico" rel="shortcut icon"/><meta content="noarchive" name="bingbot"/><meta content="width=device-width,initial-scale=1,maximum-scale=2,shrink-to-fit=no" name="viewport"/><link crossorigin="use-credentials" href="/data/manifest/" id="MANIFEST_LINK" rel="manifest"/><meta content="light" name="color-scheme"/><meta content="#FFFFFF" name="theme-color"/><style nonce="">:root{--fds-black:#000000;--fds-black-alpha-05:rgba(0, 0, 0, 0.05);--fds-black-alpha-10:rgba(0, 0, 0, 0.1);--fds-black-alpha-15:rgba(0, 0, 0, 0.15);--fds-black-alpha-20:rgba(0, 0, 0, 0.2);--fds-black-alpha-30:rgba(0, 0, 0, 0.3);--fds-black-alpha-40:rgba(0, 0, 0, 0.4);--fds-black-alpha-50:rgba(0, 0, 0, 0.5);--fds-black-alpha-60:rgba(0
# ...

# %%
#variables class into the facebook
class_div_card = 'x3ct3a4'
class_div_text = "x9f619 x78zum5 xdt5ytf x1qughib x1rdy4ex xz9dl7a xsag5q8 xh8yej3 xp0eagm x1nrcals"
class_div_title = "xyqdw3p x4uap5 xjkvuk6 xkhd6sd"
class_div_price = "x78zum5 x1q0g3np x1iorvi4 x4uap5 xjkvuk6 xkhd6sd"
class_span_title = "x193iq5w xeuugli x13faqbe x1vvkbs x10flsy6 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x x1tu3fi x3x7a5m x1lkfr7t x1lbecb7 x1s688f xzsf02u"
class_price_div = 'x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x xudqn12 x676frb x1lkfr7t x1lbecb7 x1s688f xzsf02u'
class_img = 'xt7dq6l xl1xv1r x6ikm8r x10wlt62 xh8yej3'
class_url = "x1i10hfl xjbqb8w x1ejq31n xd10rxx x1sy0etr x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 xggy1nq x1a2a7pz x1heor9g xt0b8zv x1hl2dhg x1lku1pv"
#find card x1i10hfl xjbqb8w x1ejq31n xd10rxx x1sy0etr x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 xggy1nq x1a2a7pz x1heor9g xt0b8zv x1hl2dhg x1lku1pv
car_divs = market_soup.find_all('div', class_=class_div_card)


#print(car_divs)

# %%
titles=[]

# %%
for d in car_divs:
    div_text = d.find('div', class_= class_div_text)
    # print(div_text)
   
    if div_text is not None:
        span_title = d.find('span', class_= "x1lliihq x6ikm8r x10wlt62 x1n2onr6")
        title = span_title.text if span_title is not None else "No title"
        titles.append(title)
        print("Titulo ----------->",title)
        price = d.find('div', class_=class_div_price)
        print("Precio ----------->",price.text)
        cleaned_price = int(re.sub(r'\D', '', price.text))
        print("Precio limpio----->", cleaned_price)
        img = d.find('img', class_=class_img)['src']
        print("image url--------->",img)
        url = d.find('a', class_=class_url)['href']
        url_generated =  "https://m.facebook.com"+ url
        print("url--------------->",url_generated)
        id = re.search(r"/item/(\d+)/", url).group(1)
        print("ID---------------->",id)
        formatted_price = "$"+locale.format_string("%d", cleaned_price, grouping=True)
        print("precio formateado->",formatted_price)
        
        print("-------------------------------------------------")
# Out:
# Titulo -----------> Vendo auto Gelly Eminem año 2021 papeles al día
# Precio -----------> 4 300 000 $
# Precio limpio-----> 4300000
# image url---------> https://scontent.fccp3-1.fna.fbcdn.net/v/t45.5328-4/438267931_1245509876422251_4202646636149473173_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=102&ccb=1-7&_nc_sid=247b10&_nc_ohc=XBBbOHCPmIMQ7kNvgFGSVFI&_nc_ht=scontent.fccp3-1.fna&oh=00_AfAp47J1-3lCJiuf0Zg9V9aQ5osTYdtUcY58kCru9Dwlrg&oe=6641B95E
# url---------------> https://m.facebook.com/marketplace/item/1876078159557549/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD
# ID----------------> 1876078159557549
# precio formateado-> $4300000
# -------------------------------------------------
# Titulo -----------> 1996 Toyota tercel
# Precio -----------> 3 000 000 $
# Precio limpio-----> 3000000
# ...

# %%
titles
# Out:
# Vendo auto Gelly Eminem año 2021 papeles al día
# 1996 Toyota tercel
# 2007 Mazda cx-7
# 2009 Subaru impreza
# 2005 Mazda sport wagon
# Partes y piezasMitsubishi l200
# 2008 Hyundai accent sport
# 1997 Nissan pathfinder
# 2007 Mazda 3
# 2010 Hyundai accent
# 2009 Ford fiesta
# 2007 Ford escape
# 2013 Chevrolet spark
# Ae92
# VENDO CHEVROLET SPARK
# 2001 Subaru outback
# 2005 Toyota corolla
# 2008 Toyota yaris
# 2007 Mazda 3
# 2004 Toyota yaris
# No title
# Se vende o se permuta suzuki aerio 2007 al dia y tranferible
# 2009 Mazda 3
# TOYOTA YARIS 2004 A/C AUTOMATICO
# 1997 Suzuki samurai
# 2013 MG 3 confort
# Jeep Patriot
# 2008 Chevrolet captiva ltz
# 2011 Chevrolet spark
# Se vende auto Renault Samsung sm3
# Buen estado 2008 , precio conversable
# Se vende bote 22 nuevo y 29 paños reineteros poco uso se pueden permutar por auto
# 2008 Mazda 6
# Elevador
# 2004 Toyota corolla
# 2003 Mitsubishi lancer
# 2010 Toyota yaris
# Se vende o se permuta por algún auto
# ...
